# %%
from bs4 import BeautifulSoup
import requests
import time

# %%
# Connect to website and scraping the data

URL= 'https://www.amazon.in/Titan-Moments-Analog-Womens-Watch-2606WM09/dp/B08LKVL1V9/ref=sr_1_6?crid=2ZVC587Q78X2W&dib=eyJ2IjoiMSJ9.s-_16anepZzibWiRMopy4W8CCQQeOLE_LaJIKmENND6QWCPzRnbet5UG3tFVXnMxxZYS5SNQuSrEakH7L6J_jzOuP_fyDhvZNSsRKRKBkOq8ZyPabZbOh8GGeuu9Km8phJG5CBwnDeV9TFAYeBd5xuzXvGDFtbtHKqcDIMctNTiUJoA-dk9RhbA8GIiI6143kTL3Pw0-Bmv1AoboDZhnuASs9HMjtDFNXFJjG6b83lbrzBPBvS6Fxf8iuJk6NBrauffeV6l0RX2TxQbmQxxfTs8eJiO1yommoP9uI2o9c9j36zCYYH-h5RX5JsTo6eKNUgqIEAh-rrbJu7J0dhdbAV347IhsHfhmFmXvy37Fe3xGWJCPVB9WilvllEbFDtiIbY8HcdZU4bw4DkujRa_LxakrX99Yh4UgastzcyGdXB3GnYGhTX7SpivGC0Zk417r.6PqCAmrinC0jUbuy66Kxr_tVt4ZjEUJYUnvEwOQyAcA&dib_tag=se&keywords=titan%2Braga&nsdOptOutParam=true&qid=1739345792&sprefix=titan%2Br%2Caps%2C275&sr=8-6&th=1'

headers = {"Accept": "text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.7","User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/132.0.0.0 Safari/537.36"}

page = requests.get(URL, headers=headers)

soup1 = BeautifulSoup(page.content, "html.parser")

soup2 = BeautifulSoup(soup1.prettify(), "html.parser")

print(soup2)
# Out:
# <!DOCTYPE html>
#
# <html class="a-no-js" data-19ax5a9jf="dingo" lang="en-in">
# <!-- sp:feature:head-start -->
# <head>
# <script>
#    var aPageStart = (new Date()).getTime();
#   </script>
# <meta charset="utf-8"/>
# <!-- sp:end-feature:head-start -->
# <!-- sp:feature:csm:head-open-part1 -->
# <script type="text/javascript">
#    var ue_t0=ue_t0||+new Date();
#   </script>
# <!-- sp:end-feature:csm:head-open-part1 -->
# <!-- sp:feature:cs-optimization -->
# <meta content="on" http-equiv="x-dns-prefetch-control"/>
# <link href="https://images-eu.ssl-images-amazon.com" rel="dns-prefetch"/>
# <link href="https://m.media-amazon.com" rel="dns-prefetch"/>
# <link href="https://completion.amazon.com" rel="dns-prefetch"/>
# <!-- sp:end-feature:cs-optimization -->
# <!-- sp:feature:csm:head-open-part2 -->
# <script type="text/javascript">
#    window.ue_ihb = (window.ue_ihb || window.ueinit || 0) + 1;
# if (window.ue_ihb === 1) {
#
# var ue_csm = window,
#     ue_hob = +new Date();
# ...

# %%
title = soup2.find(id='productTitle').get_text()

availability = soup2.find(id ='availability').get_text()

print(title)
print(availability)
# Out:
#              Titan Raga Women's Grace Analog Watch: Mother of Pearl Pink Dial & Rose Gold Band Ornate Bracelet Metal Watch-NS2606WM09
#
#
#
#                           In stock

# %%
title = title.strip()
availability = availability.strip()
print(title)
print(availability)
# Out:
# Titan Raga Women's Grace Analog Watch: Mother of Pearl Pink Dial & Rose Gold Band Ornate Bracelet Metal Watch-NS2606WM09
# In stock

# %%
# Day when the data was captured
import datetime

today = datetime.date.today()
print(today)
# Out:
# 2025-02-13

# %%
# csv file creation and initial insertion of data into the csv

import csv

header = ['Title', 'Availability', 'Date']
data = [title, availability, today]

with open('AmazonWebScraperdataset.csv','w', newline='' , encoding='UTF8') as f:
    writer = csv.writer(f)
    writer.writerow(header)
    writer.writerow(data)

# %%
import pandas as pd
df = pd.read_csv('AmazonWebScraperdataset.csv')
print(df)
# Out:
#                                                Title Availability        Date
# 0  Titan Raga Women's Grace Analog Watch: Mother ...     In stock  2025-02-13
# 1  Titan Raga Women's Grace Analog Watch: Mother ...     In stock  2025-02-13
# 2  Titan Raga Women's Grace Analog Watch: Mother ...     In stock  2025-02-13
# 3  Titan Raga Women's Grace Analog Watch: Mother ...     In stock  2025-02-13
# 4  Titan Raga Women's Grace Analog Watch: Mother ...     In stock  2025-02-13

# %%
# Appending data to csv

with open('AmazonWebScraperdataset.csv','a+', newline='' , encoding='UTF8') as f:
    writer = csv.writer(f)
    writer.writerow(data)

# %%
# Creating a funtion to check the availability of the product

def check_availability():
    URL= 'https://www.amazon.in/Titan-Moments-Analog-Womens-Watch-2606WM09/dp/B08LKVL1V9/ref=sr_1_6?crid=2ZVC587Q78X2W&dib=eyJ2IjoiMSJ9.s-_16anepZzibWiRMopy4W8CCQQeOLE_LaJIKmENND6QWCPzRnbet5UG3tFVXnMxxZYS5SNQuSrEakH7L6J_jzOuP_fyDhvZNSsRKRKBkOq8ZyPabZbOh8GGeuu9Km8phJG5CBwnDeV9TFAYeBd5xuzXvGDFtbtHKqcDIMctNTiUJoA-dk9RhbA8GIiI6143kTL3Pw0-Bmv1AoboDZhnuASs9HMjtDFNXFJjG6b83lbrzBPBvS6Fxf8iuJk6NBrauffeV6l0RX2TxQbmQxxfTs8eJiO1yommoP9uI2o9c9j36zCYYH-h5RX5JsTo6eKNUgqIEAh-rrbJu7J0dhdbAV347IhsHfhmFmXvy37Fe3xGWJCPVB9WilvllEbFDtiIbY8HcdZU4bw4DkujRa_LxakrX99Yh4UgastzcyGdXB3GnYGhTX7SpivGC0Zk417r.6PqCAmrinC0jUbuy66Kxr_tVt4ZjEUJYUnvEwOQyAcA&dib_tag=se&keywords=titan%2Braga&nsdOptOutParam=true&qid=1739345792&sprefix=titan%2Br%2Caps%2C275&sr=8-6&th=1'

    headers = {"Accept": "text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.7","User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/132.0.0.0 Safari/537.36"}

    page = requests.get(URL, headers=headers)

    soup1 = BeautifulSoup(page.content, "html.parser")

    soup2 = BeautifulSoup(soup1.prettify(), "html.parser")
  
    title = soup2.find(id='productTitle').get_text()

    availability = soup2.find(id ='availability').get_text()

    title = title.strip()
    availability = availability.strip()
    
    import datetime
    today = datetime.date.today()

    import csv

    header = ['Title', 'Availability', 'Date']
    data = [title, availability, today]

    with open('AmazonWebScraperdataset.csv','a+', newline='' , encoding='UTF8') as f:
        writer = csv.writer(f)
        writer.writerow(data)

# %%
# The funciton is automated and run every single day(24 hours) to check the availability of the product

while(True):
    check_availability()
    time.sleep(86400)

# %%
import pandas as pd
df = pd.read_csv('AmazonWebScraperdataset.csv')
print(df)
# Out:
#                                                 Title Availability        Date
# 0   Titan Raga Women's Grace Analog Watch: Mother ...     In stock  2025-02-13
# 1   Titan Raga Women's Grace Analog Watch: Mother ...     In stock  2025-02-13
# 2   Titan Raga Women's Grace Analog Watch: Mother ...     In stock  2025-02-13
# 3   Titan Raga Women's Grace Analog Watch: Mother ...     In stock  2025-02-13
# 4   Titan Raga Women's Grace Analog Watch: Mother ...     In stock  2025-02-13
# 5   Titan Raga Women's Grace Analog Watch: Mother ...     In stock  2025-02-13
# 6   Titan Raga Women's Grace Analog Watch: Mother ...     In stock  2025-02-13
# 7   Titan Raga Women's Grace Analog Watch: Mother ...     In stock  2025-02-13
# 8   Titan Raga Women's Grace Analog Watch: Mother ...     In stock  2025-02-13
# 9   Titan Raga Women's Grace Analog Watch: Mother ...     In stock  2025-02-13
# 10  Titan Raga Women's Grace Analog Watch: Mother ...     In stock  2025-02-13
# ...
